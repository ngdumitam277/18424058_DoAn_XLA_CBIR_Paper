# %%
import numpy as np
import cv2
import glob
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
image=cv2.imread('aa.png')
image2=cv2.imread('dd.png')
cv2.imshow("Anh truy van",image)
cv2.imshow('Anh dao tao',image2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image1=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
image2=cv2.cvtColor(image2,cv2.COLOR_BGR2GRAY)

# %%
orb=cv2.ORB_create()
kp1,descriptor1=orb.detectAndCompute(image1,None)
kp2,descriptor2=orb.detectAndCompute(image2,None)
print('Keypoint cua anh 1: ',len(kp1))
print('Keypoint cua anh 2: ',len(kp2))
# Out:
# Keypoint cua anh 1:  460
# Keypoint cua anh 2:  500

# %%
FLANN_INDEX_LSH = 6
index_params= dict(algorithm = FLANN_INDEX_LSH,
                   table_number = 6, # 12
                   key_size = 12,     # 20
                   multi_probe_level = 1) #2
search_params = dict(checks=100)

# %%
flann = cv2.FlannBasedMatcher(index_params,search_params)
matches = flann.knnMatch(descriptor1,descriptor2,k=2)
good_matches=[]
#print(matches)
for m, n in matches:
    if m.distance<=0.7*n.distance:
        good_matches.append(m)
print(len(good_matches))
image3=cv2.drawMatches(image1,kp1,image2,kp2,good_matches,None,flags=2)
fig=plt.figure(figsize=(15,15))
plt.imshow(image3)
plt.show()
# Out:
# 2

# %%
results={}
flann = cv2.FlannBasedMatcher(index_params,search_params)
for des_path in glob.glob('Descriptors/*'):
    good_matches=[]
    ImageID=des_path[des_path.rfind("\\")+1:].split('.')[0]
    desriptor=np.load(des_path,'r')
    matches = flann.knnMatch(descriptor1,desriptor,k=2)
    #print(matches)
    for list_result in matches:
        if len(list_result)==2:
            if list_result[0].distance<=0.7*list_result[1].distance:
                good_matches.append(list_result[0].distance)
    results[ImageID]=len(good_matches)
results=sorted([(v,k) for (k,v) in results.items()],reverse=True)

# %%
for (v,k) in results:
    print('ID Anh:',k)
    print('So diem anh khoang cach:',v)
# Out:
# ID Anh: homepage2niftycomhosonumabicyclepantanitdfIMG12741
# So diem anh khoang cach: 443
# ID Anh: wwwreddirtpedalerscomBicycle20Picture20ArchiveMarybike
# So diem anh khoang cach: 9
# ID Anh: photos1bloggercomimg1741145320BLUE20BICYCLE20IAG
# So diem anh khoang cach: 7
# ID Anh: wwwfredmirandacomhostingdata50132827bluebicyclefm
# So diem anh khoang cach: 6
# ID Anh: wwwbeevillenetBicycleclassic2004PhotosBeevilleBeeCountyHTEBicycleClassic2004P7106564small
# So diem anh khoang cach: 5
# ID Anh: wwwbeautifullandscapecomNew20SitedataPrints20of20the20monthBicycle500
# So diem anh khoang cach: 5
# ID Anh: wwwaea1k12iausnwinnPictures2020032004Bicycle20RodeoBicycle20RodeoImages9
# So diem anh khoang cach: 5
# ID Anh: yfieldcomveralucbicycle2desert
# So diem anh khoang cach: 4
# ID Anh: wwwyasukawacommamiarchivesimagesbicycle0429
# So diem anh khoang cach: 4
# ID Anh: wwwrivendellbicyclescomimagesbikesmainatlantis2
# So diem anh khoang cach: 4
# ID Anh: wwwmontanaeduwwwmsupdimagesbikereg
# So diem anh khoang cach: 4
# ID Anh: wwwibizaselectcomimagesbarribicycle
# So diem anh khoang cach: 4
# ID Anh: wwwexclamationsandiegohotelreservationscompictureforsandiegoBicycleTours2B
# So diem anh khoang cach: 4
# ID Anh: wwwdobradesigncompiphotogallerypischools
# So diem anh khoang cach: 4
# ID Anh: www8plalaorjpematsukaimagesbicycleDSC01512
# So diem anh khoang cach: 4
# ID Anh: wwwworldshop1comchinedirectimagesbicyclesPL26E88E20Electric20Bicycle
# So diem anh khoang cach: 3
# ID Anh: wwwmunsonbuilderscomSouthportPhotosman20on20bicycle20by20fingelly20real20estate
# So diem anh khoang cach: 3
# ID Anh: wwwmomovelocomimagescheesecheese3760
# So diem anh khoang cach: 3
# ID Anh: wwwlrghorgimagesauctionimgsBicycle
# So diem anh khoang cach: 3
# ID Anh: wwwjadedtinejpchubicyclemybikeindexfilesbd1gazomiyata26
# So diem anh khoang cach: 3
# ID Anh: wwwgoldwingworldcomSpringer205
# So diem anh khoang cach: 3
# ID Anh: wwwgatlinburgtennesseecompresskitimagesbicycle
# So diem anh khoang cach: 3
# ID Anh: wwwcityvancouverbccapoliceBicyclebike4a
# So diem anh khoang cach: 3
# ID Anh: wwwcityoforovilleorgPolicePD20PIC27SBicycle
# So diem anh khoang cach: 3
# ID Anh: wwwcamocladcomimagesbicyclemob
# So diem anh khoang cach: 3
# ID Anh: wwwbrucedalecomChina20PhotosNorthwest20Chinabicycle
# So diem anh khoang cach: 3
# ID Anh: wwwbikeiconscomimages189720Columbus20Bicycle20Co20Girls
# So diem anh khoang cach: 3
# ID Anh: wwwbigbearcabinsfrcomphotosbicycle
# So diem anh khoang cach: 3
# ID Anh: wwwbathacuksocpolimagesstonesandbicyclesept2003
# So diem anh khoang cach: 3
# ID Anh: wwwabbikecomgraphicsMiscRiders4
# So diem anh khoang cach: 3
# ID Anh: visualizationtudelftnlariweblogfietsactie1
# So diem anh khoang cach: 3
# ID Anh: branchburgnewspapertripodcomjan20editionjan20picsbicycle
# So diem anh khoang cach: 3
# ID Anh: wwwunclepashacommoscowaccommodationdutchloftbicyclesmm
# So diem anh khoang cach: 2
# ID Anh: wwwmtcntnuedutwdragonboatdb02jackimagesDayAfterSatoshionBicycle
# So diem anh khoang cach: 2
# ID Anh: wwwlpdssztakihurobertophotosGreece98bicycle
# So diem anh khoang cach: 2
# ID Anh: wwwhutsorgimagesactivitiespeoplebicyclecroppedweb
# So diem anh khoang cach: 2
# ID Anh: wwwgcmaricopaedubusinesschinajune4Man20with20Bicycle
# So diem anh khoang cach: 2
# ID Anh: wwwexclamationsandiegohotelreservationscompictureforsandiegoBicycleToursB
# So diem anh khoang cach: 2
# ID Anh: wwwchandlerpdcomcpdsiteDarePDKidsDAREVehiclesContentPagesallterrainbicycle
# So diem anh khoang cach: 2
# ID Anh: wwwbreezerbikescomstreet3
# So diem anh khoang cach: 2
# ID Anh: wwwbiriacomimagesbiriacover
# So diem anh khoang cach: 2
# ID Anh: wwwbikemotorcomimagesMariner20Encore20folding20bicycle
# So diem anh khoang cach: 2
# ID Anh: wwwacmebicyclecompanycomimagessmmine03
# So diem anh khoang cach: 2
# ID Anh: userscwnetcombrilleroriginaldbwbike2
# So diem anh khoang cach: 2
# ID Anh: ttitamueduresearcherv39n3imagesbicycle
# So diem anh khoang cach: 2
# ID Anh: todaibicyclemainjpphotohrRIMG00101
# So diem anh khoang cach: 2
# ID Anh: takachinoipcomcycletouringbicyclebrake2927
# So diem anh khoang cach: 2
# ID Anh: membersaolcombrownebicycle
# So diem anh khoang cach: 2
# ID Anh: mcduffiemirrorcomimagesheadlines06170413985512
# So diem anh khoang cach: 2
# ID Anh: hometiscalinltaudinCommonimageImagebankAmsterdamstreetcanalsOriginalsizebicycle
# So diem anh khoang cach: 2
# ID Anh: wwwumicheduurecord0405Sept0704img040907dearbornbike
# So diem anh khoang cach: 1
# ID Anh: wwwsinitscomphotoseuropedunkerquebicycle
# So diem anh khoang cach: 1
# ID Anh: wwwmolokaioutdoorscomgraphicshalawabicyclegirls
# So diem anh khoang cach: 1
# ID Anh: wwwjsdiorjpytomtopgallerybicycle
# So diem anh khoang cach: 1
# ID Anh: wwwfcjapancojpkentaweeklyimagesbicycle
# So diem anh khoang cach: 1
# ID Anh: wwwexperiencepluscomimagesemaildsc0040
# So diem anh khoang cach: 1
# ID Anh: wwwegguevaracommadisongrowingbicycle
# So diem anh khoang cach: 1
# ID Anh: wwweducanetchhomefeelthewindsamosDateienimage004
# So diem anh khoang cach: 1
# ID Anh: wwwdowntheroadorgimagesPhoto20AlbumNewFolder11DSC00089
# So diem anh khoang cach: 1
# ID Anh: wwwcsbhamacukjerphotoslofotensbicycle
# So diem anh khoang cach: 1
# ID Anh: wwwcoaraorjpmykmpkzbicycle
# So diem anh khoang cach: 1
# ID Anh: wwwcheltenhamgovuklibrariesimagesthefuturedraft20transport20planbicycle
# So diem anh khoang cach: 1
# ID Anh: wwwbjorgenetpictripbike
# So diem anh khoang cach: 1
# ID Anh: wwwbicyclestuffcomstuffforsalepicsRebecca20bike2
# So diem anh khoang cach: 1
# ID Anh: wwwbakeruedutechimagesPhotoswebbicycle
# So diem anh khoang cach: 1
# ID Anh: wwwarientercommorigifbicycle
# So diem anh khoang cach: 1
# ID Anh: wwwairliecomimages2bicycle
# So diem anh khoang cach: 1
# ID Anh: www95xnetimagesbicycle20rodeo1
# So diem anh khoang cach: 1
# ID Anh: watsennetkentbicycle
# So diem anh khoang cach: 1
# ID Anh: uwajuncocologniftycomurouroimgbicycle
# So diem anh khoang cach: 1
# ID Anh: osinftudresdendenf2mexico2003bicycle
# So diem anh khoang cach: 1
# ID Anh: imagesfbrtechcomalbumsbicyclebike13sized
# So diem anh khoang cach: 1
# ID Anh: homewangjianshuocomphotochongmingslidesshanghaibicyclestartingvanke
# So diem anh khoang cach: 1
# ID Anh: wwwwisilrecumbentscomwisilracing2003floridaflorida2003RonKauffmanTTstartsm
# So diem anh khoang cach: 0
# ID Anh: wwwukstudentlifecomTravelTransportBicycleCyclists
# So diem anh khoang cach: 0
# ID Anh: wwwtotalbikecomgalleryimages18
# So diem anh khoang cach: 0
# ID Anh: wwwsheldonbrownorgracingamericancup431
# So diem anh khoang cach: 0
# ID Anh: wwwreddirtpedalerscomBicycle20Picture20ArchiveWesbikeWesbike1
# So diem anh khoang cach: 0
# ID Anh: wwwjwoodandcompanycom2004daytonaTriumphbicycle
# So diem anh khoang cach: 0
# ID Anh: wwwgeocitiescomgregu10Bicycle
# So diem anh khoang cach: 0
# ID Anh: wwwfremontohspeedwaycombicycle
# So diem anh khoang cach: 0
# ID Anh: wwwflickrcomphotos3310203236535340N00
# So diem anh khoang cach: 0
# ID Anh: wwwdotwisconsingovsafetyvehicleimagesbikecarsredsignal2
# So diem anh khoang cach: 0
# ID Anh: wwwbalanceforlifecomimagescontenthealthtipsbicyclemain
# So diem anh khoang cach: 0
# ID Anh: kaiyacsshinshuuacjpkaiyabicycle2003fukushimaimga01112600
# So diem anh khoang cach: 0

# %%
r1=cv2.imread('bicycle/'+results[0][1]+'.png')
r2=cv2.imread('bicycle/'+results[1][1]+'.png')
r3=cv2.imread('bicycle/'+results[2][1]+'.png')
r4=cv2.imread('bicycle/'+results[3][1]+'.png')
cv2.imshow('Query Image',image)
cv2.imshow('R1',r1)
cv2.imshow('R2',r2)
cv2.imshow('R3',r3)
cv2.imshow('R4',r4)
cv2.waitKey(0)
cv2.destroyAllWindows()
